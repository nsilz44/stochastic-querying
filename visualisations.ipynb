# %% [markdown]
# VISUALISING RESULTS

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
uniformMindf = pd.read_csv('uniformityTests.csv')
uniformMindf.head(12)
# Out:
#    Unnamed: 0   Test  Number of intervals  \
# 0           0  1.3.8                   10
# 1           1  1.3.7                   10
# 2           2  1.3.6                   10
# 3           3  1.3.5                   10
# 4           4  1.3.4                   10
# 5           5  1.3.3                   10
# 6           6  1.3.2                   10
# 7           7  1.3.1                   10
#
#                           Query structure Probabilities  \
# 0       Descending high to low to uniform   All uniform
# 1                             All uniform   All uniform
# 2       Descending high to low to uniform   All uniform
# 3                             All uniform   All uniform
# 4  Descending high to low then random low   All uniform
# 5                             All uniform   All uniform
# 6  Descending high to low then random low   All uniform
# 7                             All uniform   All uniform
#
#    Expected of optimum query set  Expected of approximation algorithm  \
# 0                         34.030                               45.567
# 1                          1.135                                1.136
# 2                        103.613                              116.260
# 3                          1.962                                1.962
# 4                         44.137                               46.579
# 5                          1.088                                1.090
# 6                          1.195                                1.197
# 7                         29.179                               32.246
#
#    Expected of heuristic approximation algorithm  \
# 0                                         43.198
# 1                                          1.136
# 2                                        113.313
# 3                                          1.962
# 4                                         46.497
# 5                                          1.090
# 6                                          1.197
# 7                                         31.582
#
#    Competitive ratio of approximation algorithm  \
# 0                                      1.339024
# 1                                      1.000881
# 2                                      1.122060
# 3                                      1.000000
# 4                                      1.055328
# 5                                      1.001838
# 6                                      1.001674
# 7                                      1.105110
#
#    Competitive ratio of heuristic approximation algorithm  \
# 0                                           1.269409
# 1                                           1.000881
# 2                                           1.093618
# 3                                           1.000000
# 4                                           1.053470
# 5                                           1.001838
# 6                                           1.001674
# 7                                           1.082354
#
#    Expected competitive ratio of approximation algorithm  \
# 0                                           1.326742
# 1                                           1.000111
# 2                                           1.125291
# 3                                           1.000000
# 4                                           1.054176
# 5                                           1.000222
# 6                                           1.000222
# 7                                           1.061092
#
#    Expected competitive ratio of heuristic approximation algorithm  \
# 0                                           1.261129
# 1                                           1.000111
# 2                                           1.100750
# 3                                           1.000000
# 4                                           1.052354
# 5                                           1.000222
# 6                                           1.000222
# 7                                           1.047869
#
#    Number of simulations
# 0                   1000
# 1                   1000
# 2                   1000
# 3                   1000
# 4                   1000
# 5                   1000
# 6                   1000
# 7                   1000

# %%
probMinDf = pd.read_csv('probabilityTests.csv')
probMinDf.head(12)
# Out:
#    Unnamed: 0   Test  Number of intervals                    Query structure  \
# 0           0  1.1.6                   15  Descending high to low to uniform
# 1           1  1.1.5                   15  Descending high to low to uniform
# 2           2  1.1.4                   15  Descending high to low to uniform
# 3           3  1.1.3                   15  Descending high to low to uniform
# 4           4  1.1.2                   15  Descending high to low to uniform
# 5           5  1.1.1                   15  Descending high to low to uniform
#
#                     Probabilities  Expected of optimum query set  \
# 0       All bradford distribution                         41.921
# 1              All r-distribution                         38.246
# 2    All Gauss hyper distribution                         32.000
# 3  All semi-circular distribution                         33.191
# 4           All beta distribution                         32.144
# 5                     All uniform                         35.903
#
#    Expected of approximation algorithm  \
# 0                               54.765
# 1                               45.486
# 2                               32.000
# 3                               34.536
# 4                               32.386
# 5                               40.975
#
#    Expected of heuristic approximation algorithm  \
# 0                                         53.515
# 1                                         45.031
# 2                                         32.000
# 3                                         34.237
# 4                                         32.365
# 5                                         40.305
#
#    Competitive ratio of approximation algorithm  \
# 0                                      1.306386
# 1                                      1.189301
# 2                                      1.000000
# 3                                      1.040523
# 4                                      1.007529
# 5                                      1.141270
#
#    Competitive ratio of heuristic approximation algorithm  \
# 0                                           1.276568
# 1                                           1.177404
# 2                                           1.000000
# 3                                           1.031515
# 4                                           1.006875
# 5                                           1.122608
#
#    Expected competitive ratio of approximation algorithm  \
# 0                                           1.255873
# 1                                           1.142973
# 2                                           1.000000
# 3                                           1.026785
# 4                                           1.004840
# 5                                           1.100525
#
#    Expected competitive ratio of heuristic approximation algorithm  \
# 0                                           1.231037
# 1                                           1.134006
# 2                                           1.000000
# 3                                           1.020782
# 4                                           1.004420
# 5                                           1.087363
#
#    Number of simulations
# 0                   1000
# 1                   1000
# 2                   1000
# 3                   1000
# 4                   1000
# 5                   1000

# %%
intervalsMinDf = pd.read_csv('intervalsTests.csv')
intervalsMinDf.head(12)
# Out:
#    Unnamed: 0   Test  Number of intervals                    Query structure  \
# 0           0  1.2.5                   50  Descending high to low to uniform
# 1           1  1.2.4                   40  Descending high to low to uniform
# 2           2  1.2.3                   30  Descending high to low to uniform
# 3           3  1.2.2                   20  Descending high to low to uniform
# 4           4  1.2.1                   10  Descending high to low to uniform
#
#   Probabilities  Expected of optimum query set  \
# 0   All uniform                        135.402
# 1   All uniform                        115.822
# 2   All uniform                         93.992
# 3   All uniform                         75.207
# 4   All uniform                         54.156
#
#    Expected of approximation algorithm  \
# 0                              146.927
# 1                              126.632
# 2                              114.916
# 3                               92.631
# 4                               65.581
#
#    Expected of heuristic approximation algorithm  \
# 0                                        146.927
# 1                                        126.632
# 2                                        118.326
# 3                                         92.773
# 4                                         64.431
#
#    Competitive ratio of approximation algorithm  \
# 0                                      1.085117
# 1                                      1.093333
# 2                                      1.222615
# 3                                      1.231681
# 4                                      1.210965
#
#    Competitive ratio of heuristic approximation algorithm  \
# 0                                           1.085117
# 1                                           1.093333
# 2                                           1.258894
# 3                                           1.233569
# 4                                           1.189730
#
#    Expected competitive ratio of approximation algorithm  \
# 0                                           1.091468
# 1                                           1.101981
# 2                                           1.208589
# 3                                           1.216765
# 4                                           1.189126
#
#    Expected competitive ratio of heuristic approximation algorithm  \
# 0                                           1.091468
# 1                                           1.101981
# 2                                           1.241263
# 3                                           1.217386
# 4                                           1.170056
#
#    Number of simulations
# 0                   1000
# 1                   1000
# 2                   1000
# 3                   1000
# 4                   1000

# %%
graphDf = pd.read_csv('GraphTests.csv')
graphDf.head(20)
# Out:
#    Unnamed: 0   Test  Number of intervals  Number of edges  \
# 0           0  2.2.6                   20               30
# 1           1  2.2.5                   20               20
# 2           2  2.2.4                   20               20
# 3           3  2.2.3                   20               30
# 4           4  2.2.2                   20               19
# 5           5  2.2.1                   20               47
#
#                        Graph Edges Structure Query structure Probabilities  \
# 0  Random GNM 30 edges Graph     2 in length      descending   All uniform
# 1  Random GNM 20 edges Graph     2 in length      descending   All uniform
# 2      Random 2 degree Graph     2 in length      descending   All uniform
# 3      Random 3 degree Graph     2 in length      descending   All uniform
# 4                 Path Graph     2 in length      descending   All uniform
# 5             Bipatite Graph     2 in length      descending   All uniform
#
#    Expected of optimum query set  Expected of threshold algorithm  \
# 0                         16.708                             20.0
# 1                         16.102                             20.0
# 2                         18.932                             20.0
# 3                         19.214                             20.0
# 4                         19.831                             20.0
# 5                         18.280                             20.0
#
#    Expected of bestVc algorithm  Competitive ratio of threshold algorithm  \
# 0                        17.317                                  1.197031
# 1                        16.704                                  1.242082
# 2                        19.458                                  1.056412
# 3                        19.506                                  1.040908
# 4                        19.841                                  1.008522
# 5                        18.633                                  1.094092
#
#    Competitive ratio of bestVc algorithm  \
# 0                               1.036450
# 1                               1.037387
# 2                               1.027784
# 3                               1.015197
# 4                               1.000504
# 5                               1.019311
#
#    Expected competitive ratio of threshold algorithm  \
# 0                                           1.204160
# 1                                           1.252913
# 2                                           1.059073
# 3                                           1.042972
# 4                                           1.008936
# 5                                           1.099625
#
#    Expected competitive ratio of bestVc algorithm  Number of simulations
# 0                                        1.037292                   1000
# 1                                        1.038798                   1000
# 2                                        1.029118                   1000
# 3                                        1.015913                   1000
# 4                                        1.000529                   1000
# 5                                        1.021074                   1000

# %%
probHyperDf = pd.read_csv('hyperProbabilityTests.csv')
probHyperDf.head(20)
# Out:
#     Unnamed: 0    Test  Number of intervals  Number of edges           Graph  \
# 0            0  2.1.12                   10               14  Bipatite Graph
# 1            1  2.1.11                   10               14  Bipatite Graph
# 2            2  2.1.10                   10               14  Bipatite Graph
# 3            3   2.1.9                   10               14  Bipatite Graph
# 4            4   2.1.8                   10               14  Bipatite Graph
# 5            5   2.1.7                   10               14  Bipatite Graph
# 6            6   2.1.6                   15               10      HyperGraph
# 7            7   2.1.5                   15               10      HyperGraph
# 8            8   2.1.4                   15               10      HyperGraph
# 9            9   2.1.3                   15               10      HyperGraph
# 10          10   2.1.2                   15               10      HyperGraph
# 11          11   2.1.1                   15               10      HyperGraph
#
#                      Edges Structure Query structure      Probabilities  \
# 0                        2 in length         uniform       All bradford
# 1                        2 in length         uniform         All r-dist
# 2                        2 in length         uniform    All gauss-hyper
# 3                        2 in length         uniform  All semi-circular
# 4                        2 in length         uniform           All beta
# 5                        2 in length         uniform        All uniform
# 6   Random between 2 and 4 in length         uniform       All bradford
# 7   Random between 2 and 4 in length         uniform          All rdist
# 8   Random between 2 and 4 in length         uniform    All gauss-hyper
# 9   Random between 2 and 4 in length         uniform  All semi-circular
# 10  Random between 2 and 4 in length         uniform           All beta
# 11  Random between 2 and 4 in length         uniform        All uniform
#
#     Expected of optimum query set  Expected of approximation algorithm  \
# 0                           7.647                               10.000
# 1                           8.220                               10.000
# 2                           6.244                               10.000
# 3                           8.138                               10.000
# 4                           7.108                                9.990
# 5                           8.114                               10.000
# 6                           7.419                               15.000
# 7                           9.113                               15.000
# 8                          11.667                               14.987
# 9                           9.112                               15.000
# 10                         11.259                               14.148
# 11                          9.129                               15.000
#
#     Expected of heuristic approximation algorithm  \
# 0                                           9.338
# 1                                           8.879
# 2                                           6.248
# 3                                           8.785
# 4                                           7.161
# 5                                           8.806
# 6                                           8.686
# 7                                           9.599
# 8                                          12.719
# 9                                          10.165
# 10                                         11.461
# 11                                          9.593
#
#     Competitive ratio of approximation algorithm  \
# 0                                       1.307702
# 1                                       1.216545
# 2                                       1.601537
# 3                                       1.228803
# 4                                       1.405459
# 5                                       1.232438
# 6                                       2.021836
# 7                                       1.646000
# 8                                       1.284563
# 9                                       1.646181
# 10                                      1.256595
# 11                                      1.643115
#
#     Competitive ratio of heuristic approximation algorithm  \
# 0                                            1.221132
# 1                                            1.080170
# 2                                            1.000641
# 3                                            1.079504
# 4                                            1.007456
# 5                                            1.085285
# 6                                            1.170778
# 7                                            1.053330
# 8                                            1.090169
# 9                                            1.115562
# 10                                           1.017941
# 11                                           1.050827
#
#     Expected competitive ratio of approximation algorithm  \
# 0                                            1.359849
# 1                                            1.247123
# 2                                            1.615877
# 3                                            1.252786
# 4                                            1.447044
# 5                                            1.260536
# 6                                            2.110547
# 7                                            1.712688
# 8                                            1.290952
# 9                                            1.695186
# 10                                           1.272618
# 11                                           1.702661
#
#     Expected competitive ratio of heuristic approximation algorithm  \
# 0                                            1.264190
# 1                                            1.091208
# 2                                            1.000554
# 3                                            1.085563
# 4                                            1.007187
# 5                                            1.094867
# 6                                            1.184743
# 7                                            1.062975
# 8                                            1.091378
# 9                                            1.119865
# 10                                           1.020054
# 11                                           1.060041
#
#     Number of simulations
# 0                    1000
# 1                    1000
# 2                    1000
# 3                    1000
# 4                    1000
# 5                    1000
# 6                    1000
# 7                    1000
# 8                    1000
# 9                    1000
# 10                   1000
# 11                   1000

# %%
hyperGraphDf = pd.read_csv('hyperGraphTests.csv')
hyperGraphDf.head(12)
# Out:
#    Unnamed: 0   Test  Number of intervals  Number of edges           Graph  \
# 0           0  2.2.1                   20               47  Bipatite Graph
#
#   Edges Structure Query structure Probabilities  \
# 0     2 in length         uniform   All uniform
#
#    Expected of optimum query set  Expected of threshold algorithm  \
# 0                        185.917                            210.0
#
#    Expected of bestVc algorithm  Competitive ratio of threshold algorithm  \
# 0                       187.287                                  1.129536
#
#    Competitive ratio of bestVc algorithm  \
# 0                               1.007369
#
#    Expected competitive ratio of threshold algorithm  \
# 0                                           1.145261
#
#    Expected competitive ratio of bestVc algorithm  Number of simulations
# 0                                        1.007332                   1000
